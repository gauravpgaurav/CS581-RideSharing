# %%
import pandas as pd
import numpy as np
import googlemaps
from datetime import datetime

# %%
df = pd.read_csv('RideSharingData/yellow_tripdata_2016-01.csv')

# %%
df
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 1                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 2                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 3                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 4                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 5                2  2016-01-01 00:00:00   2016-01-01 00:18:30
# 6                2  2016-01-01 00:00:00   2016-01-01 00:26:45
# 7                1  2016-01-01 00:00:01   2016-01-01 00:11:55
# 8                1  2016-01-01 00:00:02   2016-01-01 00:11:14
# 9                2  2016-01-01 00:00:02   2016-01-01 00:11:08
# 10               2  2016-01-01 00:00:03   2016-01-01 00:06:19
# 11               2  2016-01-01 00:00:03   2016-01-01 00:15:49
# 12               2  2016-01-01 00:00:03   2016-01-01 00:00:11
# 13               1  2016-01-01 00:00:04   2016-01-01 00:14:32
# ...

# %%
df.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 1         2  2016-01-01 00:00:00   2016-01-01 00:00:00                5
# 2         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 4         2  2016-01-01 00:00:00   2016-01-01 00:00:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.990372        40.734695           1
# 1           4.90        -73.980782        40.729912           1
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 4           1.76        -73.960625        40.781330           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
class Request:

    def __init__(self, req_id, no_of_passengers, will_to_walk, 
                 dest_id,req_time, max_delay):
        
        self.req_id = req_id
        self.no_of_passengers = no_of_passengers
        self.will_to_walk = will_to_walk
        #self.origin_lon = origin_lon
        #self.origin_lat = origin_lat
        self.dest_id = dest_id
        #self.dest_lon = dest_lon
        #self.dest_lat = dest_lat
        self.req_time = req_time
        self.max_delay = max_delay

# %%
def fetch_long_lat_for_dest_id(dest_id):

    #TODO
    #long_lat 52.2296756, 21.0122287 , 52.406374, 16.9251681
    long = 51.234567
    lat = 15.567456
    return long, lat

# %%
class Destination:
    
    def __init__(self, dest_id):
                
        long, lat = fetch_long_lat_for_dest_id(dest_id)
        self.dest_id = dest_id
        self.long = long
        self.lat = lat
        #self.dist_from_src = dist_from_src
        #self.time_to_reach = time_to_reach
    
    

    
    def calculate_dist_from_src(self):
        src_long = 44.406374
        src_lat = 20.406374
        dist_from_src = geopy.distance.vincenty((src_long, src_lat), (self.long, self.lat)).km
        return dist_from_src 
    
    def calculate_time_to_reach():
        #TODO
        return 0

# %%
dest1 = Destination(1)
dest2 = Destination(2)

dest1.calculate_dist_from_src()
# Out:
# C:\Users\mayur\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
# 840.7888131292325

# %%
class ReqRideAllotment:
    
    def __init__(self, req_id, ride_id, shr_time, shr_dist, shr_cost):
        
        self.req_id = req_id
        self.ride_id = ride_id
        self.shr_time = shr_time
        self.shr_dist = shr_dist
        self.shr_cost = shr_cost

# %%
# Instantiate the RideRequest object for now
reqA = Request(1, 1, 'Y', 1, 10, 10)
reqB = Request(2, 2, 'Y', 2, 10, 10)


all_req_t_slot_1 = [reqA, reqB]
all_req_t_slot_1
# Out:
# [<__main__.Request at 0x1fca352eb38>, <__main__.Request at 0x1fca352e940>]

# %%
def sharability_graph(all_req_t_slot_1):
    
    taxi_capacity = 3
    for reqA in all_req_t_slot_1:
        for reqB in all_req_t_slot_1:
            if reqA != reqB and reqA.no_of_passengers + reqB.no_of_passengers <= taxi_capacity:

                reqA_orgin_dest_dist = Destination(reqA.dest_id).calculate_dist_from_src()
                reqB_orgin_dest_dist = Destination(reqB.dest_id).calculate_dist_from_src()
                
                #print('reqA_orgin_dest_dist: ',reqA_orgin_dest_dist)
                #print('reqB_orgin_dest_dist: ',reqB_orgin_dest_dist)

# %%
sharability_graph(all_req_t_slot_1)
# Out:
# C:\Users\mayur\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.

# %%
import geopy.distance

coords_1 = (52.2296756, 21.0122287)
coords_2 = (52.406374, 16.9251681)

print(geopy.distance.vincenty(coords_1, coords_2).km)
# Out:
# 279.35290160386563
# C:\Users\mayur\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.

# %%
#gmaps = googlemaps.Client(key = )
